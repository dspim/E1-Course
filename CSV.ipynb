# %%
# %matplotlib inline 
#move up
# %pylab inline 
# Must get this or you will get # NameError: name 'figsize' is not defined

import pandas as pd
import matplotlib.pylab
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import matplotlib.pylab
pd.set_option('display.mpl_style', 'default') # Make the graphs a bit prettier
figsize(15, 5)

# %%
pd.set_option('html',False)

# %%
from IPython.core.display import Image
Image('http://dsp.im/wp-content/uploads/2014/10/DSP_LOGO1.png')

# %%
bike_df = pd.read_csv('ubikeCSV.csv', encoding='latin1',dayfirst=True)

# %%
bike_df.shape
# Out:
# (173, 22)

# %%
bike_df[:3]
# Out:
#     id  retCode  iid  sv                   sd  vtyp  sno  \
# 0  343        1  339   1  2000-01-01 00:00:00     1    1
# 1  344        1  340   1  2000-01-01 00:00:00     1    2
# 2  345        1  341   1  2000-01-01 00:00:00     1    3
#
#                                     sna         sip  tot ...   \
# 0        æ·éå¸æ¿åºç«(3èåºå£)   10.7.0.11  180 ...
# 1  æ·éåç¶ç´å¿µé¤¨ç«(2èåºå£)  10.250.2.1   48 ...
# 2                       å°åå¸æ¿åº  10.250.3.1   40 ...
#
#                   mday        lat         lng  \
# 0  2014-08-27 22:36:16  25.040858  121.567904
# 1  2014-08-27 22:36:17  25.041000  121.556945
# 2  2014-08-27 22:36:22  25.037797  121.565169
#
#                                               ar      sareaen  \
# 0              å¿ å­æ±è·¯/æ¾ä»è·¯(æ±åå´)  Xinyi Dist.
# 1  å¿ å­æ±è·¯åæ®µ/åå¾©åè·¯å£(è¥¿åå´)   Daan Dist.
# 2              å°åå¸æ¿åºæ±é(æ¾æºè·¯)   Xinyi Dist.
#
# ...

# %%
bike_df['snaen']
# Out:
# 0           MRT Taipei City Hall Stataion(Exit 3)-2
# 1         MRT S.Y.S Memorial Hall Stataion(Exit 2.)
# 2                                  Taipei City Hall
# 3                                    Citizen Square
# 4                            Xingya Jr. High School
# 5                            TWTC Exhibition Hall 2
# 6                          Xinyi Square(Taipei 101)
# 7                            TWTC Exhibition Hall 3
# 8                                            Songde
# 9        Emergency Operations Center of Taipei City
# 10                                       Sanchangli
# 11                        Taipei Medical University
# 12                                        Fude Park
# 13                                    Rongxing Park
# 14                               Raohe Night Market
# 15                  Songshan Vocational High School
# 16                  Minsheng & Guangfu Intersection
# 17                           Taipei Cultural Center
# ...

# %%
bike_df['bemp'].plot()
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family [u'monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from matplotlib.font_manager import FontProperties, findfont

fp = FontProperties(family='monospace', 
                    style='normal',
                    variant='normal',
                    weight='normal',
                    stretch='normal',
                    size='medium')
                  
font = findfont(fp)

# %%
bike_df['bemp'].plot()

# %%
bike_df.plot(figsize=(15,5)) # with title

# %%
bike_df.plot(subplots=True,figsize=(15,5)) # with title
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f8b28543290>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f8b23dd2a50>], dtype=object)

# %%
bike_df['平均空位數'] = bike_df['平均空位數'].convert_objects(convert_numeric=True)
# 轉換數字

# %%
# Check data type of the columns
bike_df.dtypes
# Out:
# 日期         object
# 時間         object
# 場站代號       object
# 場站區域       object
# 場站名稱       object
# 經度         object
# 緯度         object
# 總停車格       object
# 平均車輛數      object
# 最大車輛數      object
# 最小車輛數      object
# 車輛數標準差     object
# 平均空位數     float64
# 最大空位數      object
# 最小空位數      object
# 空位數標準差     object
# 氣溫         object
# 最高溫        object
# 最低溫        object
# 溼度         object
# 氣壓         object
# 最大風速       object
# 降雨量        object
# dtype: object

# %%
# Method 1:
Sorted = bike_df.sort(['平均空位數'], ascending=False)
Sorted[:1]
# Out:
#                日期  時間 場站代號 場站區域          場站名稱        經度        緯度 總停車格  平均車輛數  \
# 45085  2014-12-16  23    1  信義區  捷運市政府站(3號出口)  25.04086  121.5679  180  0.067
#
#       最大車輛數 ...  最大空位數 最小空位數  空位數標準差   氣溫  最高溫  最低溫   溼度   氣壓 最大風速  降雨量
# 45085     1 ...    180   179       0  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [1 rows x 23 columns]

# %%
bike_df['平均空位數'].plot()
